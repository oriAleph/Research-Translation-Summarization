# %%
# !pip install datasets transformers rouge-score nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: datasets in /usr/local/lib/python3.7/dist-packages (2.6.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.7/dist-packages (4.24.0)
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (3.7)
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.10.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from datasets) (1.21.6)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.13)
# Requirement already satisfied: responses<0.19 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.18.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (2.23.0)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.7/dist-packages (from datasets) (3.1.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.10.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from datasets) (21.3)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (4.64.1)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.3)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from datasets) (4.13.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.1.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0.0,>=0.2.0->datasets) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->datasets) (3.0.9)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2022.9.24)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->datasets) (1.25.11)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (0.13.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.7/dist-packages (from rouge-score) (1.15.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.7/dist-packages (from rouge-score) (1.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk) (7.1.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->datasets) (3.10.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)

# %%
from huggingface_hub import notebook_login
notebook_login()
# Out:
# Login successful
# Your token has been saved to /root/.huggingface/token

# %%
# !apt install git-lfs
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# git-lfs is already the newest version (2.3.4-1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 4 not upgraded.

# %%
from datasets import load_dataset, load_metric
from transformers import AutoTokenizer
from transformers import DataCollatorForSeq2Seq
from transformers import AutoModelForSeq2SeqLM, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import AutoModelForSeq2SeqLM, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer
from transformers import create_optimizer, AdamWeightDecay
from transformers import AutoConfig
from transformers import T5Model
import nltk
import numpy as np
nltk.download('punkt')

metric = load_metric("rouge")
tokenizer = 0
prefix = "summarize: "
max_input_length = 1024
max_target_length = 128


#adds padding to input before traing the model on the dataset
def preprocess_function(examples):
    inputs = [prefix + doc for doc in examples["article"]]
    model_inputs = tokenizer(inputs, max_length=max_input_length, truncation=True)

    # Setup the tokenizer for targets
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(examples["abstract"], max_length=max_target_length, truncation=True)

    model_inputs["labels"] = labels["input_ids"]
    return model_inputs



#tokenizer for the dataset
def my_tokenize(model_checkpoint, dataset, subset):
  global tokenizer

  sum = load_dataset(dataset, subset)

  tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)
  tokenized_sum = sum.map(preprocess_function, batched=True)

  return (tokenizer, tokenized_sum)


#create new summerization model
def get_model(model_checkpoint, tokenizer):
  #make a model that is not pre-trained
  config = AutoConfig.from_pretrained(model_checkpoint)
  
  model = AutoModelForSeq2SeqLM.from_config(config)
  model.init_weights()

  data_collator = DataCollatorForSeq2Seq(tokenizer=tokenizer, model=model)
  return (model, data_collator)


def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
    # Replace -100 in the labels as we can't decode them.
    labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
    decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
    
    # Rouge expects a newline after each sentence
    decoded_preds = ["\n".join(nltk.sent_tokenize(pred.strip())) for pred in decoded_preds]
    decoded_labels = ["\n".join(nltk.sent_tokenize(label.strip())) for label in decoded_labels]
    
    result = metric.compute(predictions=decoded_preds, references=decoded_labels, use_stemmer=True)
    # Extract a few results
    result = {key: value.mid.fmeasure * 100 for key, value in result.items()}
    
    # Add mean generated length
    prediction_lens = [np.count_nonzero(pred != tokenizer.pad_token_id) for pred in predictions]
    result["gen_len"] = np.mean(prediction_lens)
    
    return {k: round(v, 4) for k, v in result.items()}


#set hyper paramaters
#change hyper paramters for better trained model
def get_my_hyper_params(model_checkpoint, my_epochs, floating_point):
  batch_size = 16
  model_name = model_checkpoint
  args = Seq2SeqTrainingArguments(
      f"{model_name}-science-papers",
      evaluation_strategy = "epoch",
      learning_rate=2e-5,
      per_device_train_batch_size=batch_size,
      per_device_eval_batch_size=batch_size,
      weight_decay=0.01,
      save_total_limit=20,
      num_train_epochs=my_epochs,
      predict_with_generate=True,
      fp16=floating_point,
      push_to_hub=True,
  )

  return args

#make the trainer
def get_trainer(model, tokenizer, tokenized_sum, data_collator, training_args):
  trainer = Seq2SeqTrainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_sum["train"],
    eval_dataset=tokenized_sum["test"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics
	)
  return trainer
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def my_train_model():
  model_name = "t5-small"
  dataset = "scientific_papers"
  subset = "arxiv"
  epochs = 5
  floating_point = True

  token_tuple = my_tokenize(model_name, dataset, subset)

  model_tuple = get_model(model_name, token_tuple[0])

  params = get_my_hyper_params(model_name, epochs, floating_point)

  trainer = get_trainer(model_tuple[0], token_tuple[0], token_tuple[1], model_tuple[1], params)

  trainer.train()

  return trainer

# %%
trainer = my_train_model()
# Out:
# Downloading builder script:   0%|          | 0.00/5.35k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/4.99k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/7.46k [00:00<?, ?B/s]
# Downloading and preparing dataset scientific_papers/arxiv (download: 4.20 GiB, generated: 7.06 GiB, post-processed: Unknown size, total: 11.26 GiB) to /root/.cache/huggingface/datasets/scientific_papers/arxiv/1.1.1/306757013fb6f37089b6a75469e6638a553bd9f009484938d8f75a4c5e84206f...
# Downloading data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0.00/3.62G [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/880M [00:00<?, ?B/s]
# Extracting data files:   0%|          | 0/2 [00:00<?, ?it/s]
# Generating train split:   0%|          | 0/203037 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/6436 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/6440 [00:00<?, ? examples/s]
# Dataset scientific_papers downloaded and prepared to /root/.cache/huggingface/datasets/scientific_papers/arxiv/1.1.1/306757013fb6f37089b6a75469e6638a553bd9f009484938d8f75a4c5e84206f. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]
# Downloading:   0%|          | 0.00/1.20k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.39M [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/models/t5/tokenization_t5_fast.py:166: FutureWarning: This tokenizer was incorrectly instantiated with a model max length of 512 which will be corrected in Transformers v5.
# For now, this behavior is kept to avoid breaking backwards compatibility when padding/encoding with `truncation is True`.
# - Be aware that you SHOULD NOT rely on t5-small automatically truncating your input to 512 when padding/encoding.
# - If you want to encode/pad to sequences longer than 512 you can either instantiate this tokenizer with `model_max_length` or pass `max_length` when encoding/padding.
# - To avoid this warning, please instantiate this tokenizer with `model_max_length` set to your preferred value.
#   FutureWarning,
#   0%|          | 0/204 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/transformers/tokenization_utils_base.py:3547: UserWarning: `as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your labels by using the argument `text_target` of the regular `__call__` method (either in the same call as your input texts if you use the same keyword arguments, or in a separate call.
#   "`as_target_tokenizer` is deprecated and will be removed in v5 of Transformers. You can tokenize your "
#   0%|          | 0/7 [00:00<?, ?ba/s]
#   0%|          | 0/7 [00:00<?, ?ba/s]
# /usr/local/lib/python3.7/dist-packages/huggingface_hub/repository.py:708: FutureWarning: Creating a repository through 'clone_from' is deprecated and will be removed in v0.11.
#   FutureWarning,
# Cloning https://huggingface.co/Dagar/t5-small-science-papers into local empty directory.
# WARNING:huggingface_hub.repository:Cloning https://huggingface.co/Dagar/t5-small-science-papers into local empty directory.
# Using cuda_amp half precision backend
# The following columns in the training set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: abstract, section_names, article. If abstract, section_names, article are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 203037
#   Num Epochs = 5
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 63450
#   Number of trainable parameters = 60506624
# You're using a T5TokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='55992' max='63450' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [55992/63450 3:19:10 < 26:31, 4.69 it/s, Epoch 4.41/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.473500</td>
#       <td>4.372655</td>
#       <td>9.960400</td>
#       <td>1.764100</td>
#       <td>8.621300</td>
#       <td>9.277900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.010400</td>
#       <td>3.938435</td>
#       <td>11.400100</td>
#       <td>2.147400</td>
#       <td>9.651600</td>
#       <td>10.660200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.823700</td>
#       <td>3.757975</td>
#       <td>11.180600</td>
#       <td>2.122900</td>
#       <td>9.388100</td>
#       <td>10.385300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.738200</td>
#       <td>3.673797</td>
#       <td>11.929800</td>
#       <td>2.322200</td>
#       <td>9.907700</td>
#       <td>11.045000</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to t5-small-science-papers/checkpoint-500
# Configuration saved in t5-small-science-papers/checkpoint-500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-500/special_tokens_map.json
# tokenizer config file saved in t5-small-science-papers/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-1000
# Configuration saved in t5-small-science-papers/checkpoint-1000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-1000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-1500
# Configuration saved in t5-small-science-papers/checkpoint-1500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-1500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-2000
# Configuration saved in t5-small-science-papers/checkpoint-2000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-2000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-2500
# Configuration saved in t5-small-science-papers/checkpoint-2500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-2500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-3000
# Configuration saved in t5-small-science-papers/checkpoint-3000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-3000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-3500
# Configuration saved in t5-small-science-papers/checkpoint-3500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-3500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-4000
# Configuration saved in t5-small-science-papers/checkpoint-4000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-4000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-4500
# Configuration saved in t5-small-science-papers/checkpoint-4500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-4500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-5000
# Configuration saved in t5-small-science-papers/checkpoint-5000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-5000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-5500
# Configuration saved in t5-small-science-papers/checkpoint-5500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-5500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-6000
# Configuration saved in t5-small-science-papers/checkpoint-6000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-6000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-6500
# Configuration saved in t5-small-science-papers/checkpoint-6500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-6500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-7000
# Configuration saved in t5-small-science-papers/checkpoint-7000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-7000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-7500
# Configuration saved in t5-small-science-papers/checkpoint-7500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-7500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-8000
# Configuration saved in t5-small-science-papers/checkpoint-8000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-8000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-8500
# Configuration saved in t5-small-science-papers/checkpoint-8500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-8500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-9000
# Configuration saved in t5-small-science-papers/checkpoint-9000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-9000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-9500
# Configuration saved in t5-small-science-papers/checkpoint-9500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-9500/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-10000
# Configuration saved in t5-small-science-papers/checkpoint-10000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-10000/special_tokens_map.json
# Saving model checkpoint to t5-small-science-papers/checkpoint-10500
# Configuration saved in t5-small-science-papers/checkpoint-10500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-10500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-11000
# Configuration saved in t5-small-science-papers/checkpoint-11000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-11000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-1000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-11500
# Configuration saved in t5-small-science-papers/checkpoint-11500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-11500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-1500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-12000
# Configuration saved in t5-small-science-papers/checkpoint-12000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-12000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-2000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-12500
# Configuration saved in t5-small-science-papers/checkpoint-12500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-12500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-2500] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: abstract, section_names, article. If abstract, section_names, article are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 6440
#   Batch size = 16
# Saving model checkpoint to t5-small-science-papers/checkpoint-13000
# Configuration saved in t5-small-science-papers/checkpoint-13000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-13000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-3000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-13500
# Configuration saved in t5-small-science-papers/checkpoint-13500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-13500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-3500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-14000
# Configuration saved in t5-small-science-papers/checkpoint-14000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-14000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-4000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-14500
# Configuration saved in t5-small-science-papers/checkpoint-14500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-14500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-4500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-15000
# Configuration saved in t5-small-science-papers/checkpoint-15000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-15000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-5000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-15500
# Configuration saved in t5-small-science-papers/checkpoint-15500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-15500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-5500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-16000
# Configuration saved in t5-small-science-papers/checkpoint-16000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-16000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-6000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-16500
# Configuration saved in t5-small-science-papers/checkpoint-16500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-16500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-6500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-17000
# Configuration saved in t5-small-science-papers/checkpoint-17000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-17000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-7000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-17500
# Configuration saved in t5-small-science-papers/checkpoint-17500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-17500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-7500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-18000
# Configuration saved in t5-small-science-papers/checkpoint-18000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-18000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-8000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-18500
# Configuration saved in t5-small-science-papers/checkpoint-18500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-18500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-8500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-19000
# Configuration saved in t5-small-science-papers/checkpoint-19000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-19000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-9000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-19500
# Configuration saved in t5-small-science-papers/checkpoint-19500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-19500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-9500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-20000
# Configuration saved in t5-small-science-papers/checkpoint-20000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-20000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-10000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-20500
# Configuration saved in t5-small-science-papers/checkpoint-20500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-20500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-10500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-21000
# Configuration saved in t5-small-science-papers/checkpoint-21000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-21000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-11000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-21500
# Configuration saved in t5-small-science-papers/checkpoint-21500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-21500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-11500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-22000
# Configuration saved in t5-small-science-papers/checkpoint-22000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-22000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-12000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-22500
# Configuration saved in t5-small-science-papers/checkpoint-22500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-22500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-12500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-23000
# Configuration saved in t5-small-science-papers/checkpoint-23000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-23000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-23000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-23000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-13000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-23500
# Configuration saved in t5-small-science-papers/checkpoint-23500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-23500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-23500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-23500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-13500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-24000
# Configuration saved in t5-small-science-papers/checkpoint-24000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-24000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-24000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-24000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-14000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-24500
# Configuration saved in t5-small-science-papers/checkpoint-24500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-24500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-24500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-24500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-14500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-25000
# Configuration saved in t5-small-science-papers/checkpoint-25000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-25000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-25000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-25000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-15000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: abstract, section_names, article. If abstract, section_names, article are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 6440
#   Batch size = 16
# Saving model checkpoint to t5-small-science-papers/checkpoint-25500
# Configuration saved in t5-small-science-papers/checkpoint-25500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-25500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-25500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-25500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-15500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-26000
# Configuration saved in t5-small-science-papers/checkpoint-26000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-26000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-26000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-26000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-16000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-26500
# Configuration saved in t5-small-science-papers/checkpoint-26500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-26500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-26500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-26500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-16500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-27000
# Configuration saved in t5-small-science-papers/checkpoint-27000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-27000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-27000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-27000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-17000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-27500
# Configuration saved in t5-small-science-papers/checkpoint-27500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-27500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-27500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-27500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-17500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-28000
# Configuration saved in t5-small-science-papers/checkpoint-28000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-28000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-28000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-28000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-18000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-28500
# Configuration saved in t5-small-science-papers/checkpoint-28500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-28500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-28500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-28500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-18500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-29000
# Configuration saved in t5-small-science-papers/checkpoint-29000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-29000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-29000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-29000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-19000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-29500
# Configuration saved in t5-small-science-papers/checkpoint-29500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-29500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-29500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-29500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-19500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-30000
# Configuration saved in t5-small-science-papers/checkpoint-30000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-30000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-30000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-30000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-20000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-30500
# Configuration saved in t5-small-science-papers/checkpoint-30500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-30500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-30500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-30500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-20500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-31000
# Configuration saved in t5-small-science-papers/checkpoint-31000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-31000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-31000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-31000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-21000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-31500
# Configuration saved in t5-small-science-papers/checkpoint-31500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-31500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-31500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-31500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-21500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-32000
# Configuration saved in t5-small-science-papers/checkpoint-32000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-32000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-32000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-32000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-22000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-32500
# Configuration saved in t5-small-science-papers/checkpoint-32500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-32500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-32500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-32500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-22500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-33000
# Configuration saved in t5-small-science-papers/checkpoint-33000/config.json
# Model weights saved in t5-small-science-papers/checkpoint
/config.json
# Model weights saved in t5-small-science-papers/checkpoint-55500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-55500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-55500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-45500] due to args.save_total_limit
#     <div>
#
#       <progress value='63450' max='63450' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [63450/63450 3:47:00, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Rouge1</th>
#       <th>Rouge2</th>
#       <th>Rougel</th>
#       <th>Rougelsum</th>
#       <th>Gen Len</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.473500</td>
#       <td>4.372655</td>
#       <td>9.960400</td>
#       <td>1.764100</td>
#       <td>8.621300</td>
#       <td>9.277900</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.010400</td>
#       <td>3.938435</td>
#       <td>11.400100</td>
#       <td>2.147400</td>
#       <td>9.651600</td>
#       <td>10.660200</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.823700</td>
#       <td>3.757975</td>
#       <td>11.180600</td>
#       <td>2.122900</td>
#       <td>9.388100</td>
#       <td>10.385300</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.738200</td>
#       <td>3.673797</td>
#       <td>11.929800</td>
#       <td>2.322200</td>
#       <td>9.907700</td>
#       <td>11.045000</td>
#       <td>19.000000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.699400</td>
#       <td>3.640550</td>
#       <td>12.356800</td>
#       <td>2.444900</td>
#       <td>10.237100</td>
#       <td>11.420900</td>
#       <td>19.000000</td>
#     </tr>
#   </tbody>
# </table><p>
# Saving model checkpoint to t5-small-science-papers/checkpoint-56000
# Configuration saved in t5-small-science-papers/checkpoint-56000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-56000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-56000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-56000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-46000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-56500
# Configuration saved in t5-small-science-papers/checkpoint-56500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-56500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-56500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-56500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-46500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-57000
# Configuration saved in t5-small-science-papers/checkpoint-57000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-57000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-57000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-57000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-47000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-57500
# Configuration saved in t5-small-science-papers/checkpoint-57500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-57500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-57500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-57500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-47500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-58000
# Configuration saved in t5-small-science-papers/checkpoint-58000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-58000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-58000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-58000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-48000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-58500
# Configuration saved in t5-small-science-papers/checkpoint-58500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-58500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-58500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-58500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-48500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-59000
# Configuration saved in t5-small-science-papers/checkpoint-59000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-59000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-59000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-59000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-49000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-59500
# Configuration saved in t5-small-science-papers/checkpoint-59500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-59500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-59500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-59500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-49500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-60000
# Configuration saved in t5-small-science-papers/checkpoint-60000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-60000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-60000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-60000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-50000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-60500
# Configuration saved in t5-small-science-papers/checkpoint-60500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-60500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-60500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-60500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-50500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-61000
# Configuration saved in t5-small-science-papers/checkpoint-61000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-61000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-61000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-61000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-51000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-61500
# Configuration saved in t5-small-science-papers/checkpoint-61500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-61500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-61500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-61500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-51500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-62000
# Configuration saved in t5-small-science-papers/checkpoint-62000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-62000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-62000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-62000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-52000] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-62500
# Configuration saved in t5-small-science-papers/checkpoint-62500/config.json
# Model weights saved in t5-small-science-papers/checkpoint-62500/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-62500/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-62500/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-52500] due to args.save_total_limit
# Saving model checkpoint to t5-small-science-papers/checkpoint-63000
# Configuration saved in t5-small-science-papers/checkpoint-63000/config.json
# Model weights saved in t5-small-science-papers/checkpoint-63000/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/checkpoint-63000/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/checkpoint-63000/special_tokens_map.json
# Deleting older checkpoint [t5-small-science-papers/checkpoint-53000] due to args.save_total_limit
# The following columns in the evaluation set don't have a corresponding argument in `T5ForConditionalGeneration.forward` and have been ignored: abstract, section_names, article. If abstract, section_names, article are not expected by `T5ForConditionalGeneration.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 6440
#   Batch size = 16
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)

# %%
trainer.push_to_hub()
# Out:
# Saving model checkpoint to t5-small-science-papers
# Configuration saved in t5-small-science-papers/config.json
# Model weights saved in t5-small-science-papers/pytorch_model.bin
# tokenizer config file saved in t5-small-science-papers/tokenizer_config.json
# Special tokens file saved in t5-small-science-papers/special_tokens_map.json
# Several commits (2) will be pushed upstream.
# WARNING:huggingface_hub.repository:Several commits (2) will be pushed upstream.
# The progress bars may be unreliable.
# WARNING:huggingface_hub.repository:The progress bars may be unreliable.
# Upload file pytorch_model.bin:   0%|          |
 (stored 0%)
#   adding: content/t5-small-science-papers/.git/objects/c7/04b0962e7920e77f044fc2cbe2dd549cd88e3a (stored 0%)
#   adding: content/t5-small-science-papers/.git/packed-refs (deflated 9%)
#   adding: content/t5-small-science-papers/.git/logs/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/logs/HEAD (deflated 49%)
#   adding: content/t5-small-science-papers/.git/logs/refs/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/logs/refs/heads/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/logs/refs/heads/main (deflated 49%)
#   adding: content/t5-small-science-papers/.git/logs/refs/remotes/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/logs/refs/remotes/origin/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/logs/refs/remotes/origin/HEAD (deflated 22%)
#   adding: content/t5-small-science-papers/.git/logs/refs/remotes/origin/main (deflated 46%)
#   adding: content/t5-small-science-papers/.git/branches/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/description (deflated 14%)
#   adding: content/t5-small-science-papers/.git/refs/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/refs/heads/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/refs/heads/main (stored 0%)
#   adding: content/t5-small-science-papers/.git/refs/tags/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/refs/remotes/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/refs/remotes/origin/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/refs/remotes/origin/HEAD (stored 0%)
#   adding: content/t5-small-science-papers/.git/refs/remotes/origin/main (stored 0%)
#   adding: content/t5-small-science-papers/.git/COMMIT_EDITMSG (stored 0%)
#   adding: content/t5-small-science-papers/.git/ORIG_HEAD (stored 0%)
#   adding: content/t5-small-science-papers/.git/index (deflated 36%)
#   adding: content/t5-small-science-papers/.git/info/ (stored 0%)
#   adding: content/t5-small-science-papers/.git/info/exclude (deflated 28%)
#   adding: content/t5-small-science-papers/checkpoint-62500/ (stored 0%)
#   adding: content/t5-small-science-papers/checkpoint-62500/scaler.pt (deflated 55%)
#   adding: content/t5-small-science-papers/checkpoint-62500/training_args.bin (deflated 47%)
#   adding: content/t5-small-science-papers/checkpoint-62500/scheduler.pt (deflated 49%)
#   adding: content/t5-small-science-papers/checkpoint-62500/tokenizer_config.json (deflated 83%)
#   adding: content/t5-small-science-papers/checkpoint-62500/pytorch_model.bin (deflated 7%)
#   adding: content/t5-small-science-papers/checkpoint-62500/tokenizer.json (deflated 74%)
#   adding: content/t5-small-science-papers/checkpoint-62500/config.json (deflated 62%)
#   adding: content/t5-small-science-papers/checkpoint-62500/optimizer.pt (deflated 9%)
#   adding: content/t5-small-science-papers/checkpoint-62500/trainer_state.json (deflated 82%)
#   adding: content/t5-small-science-papers/checkpoint-62500/special_tokens_map.json (deflated 86%)
#   adding: content/t5-small-science-papers/checkpoint-62500/rng_state.pth (deflated 27%)
#   adding: content/t5-small-science-papers/checkpoint-56000/ (stored 0%)
#   adding: content/t5-small-science-papers/checkpoint-56000/scaler.pt (deflated 55%)
#   adding: content/t5-small-science-papers/checkpoint-56000/training_args.bin (deflated 47%)
#   adding: content/t5-small-science-papers/checkpoint-56000/scheduler.pt (deflated 49%)
#   adding: content/t5-small-science-papers/checkpoint-56000/tokenizer_config.json (deflated 83%)
#   adding: content/t5-small-science-papers/checkpoint-56000/pytorch_model.bin (deflated 7%)
#   adding: content/t5-small-science-papers/checkpoint-56000/tokenizer.json (deflated 74%)
#   adding: content/t5-small-science-papers/checkpoint-56000/config.json (deflated 62%)
#   adding: content/t5-small-science-papers/checkpoint-56000/optimizer.pt (deflated 9%)
#   adding: content/t5-small-science-papers/checkpoint-56000/trainer_state.json (deflated 82%)
#   adding: content/t5-small-science-papers/checkpoint-56000/special_tokens_map.json (deflated 86%)
#   adding: content/t5-small-science-papers/checkpoint-56000/rng_state.pth (deflated 27%)
#   adding: content/t5-small-science-papers/checkpoint-55500/ (stored 0%)
#   adding: content/t5-small-science-papers/checkpoint-55500/scaler.pt (deflated 55%)
#   adding: content/t5-small-science-papers/checkpoint-55500/training_args.bin (deflated 47%)
#   adding: content/t5-small-science-papers/checkpoint-55500/scheduler.pt (deflated 49%)
#   adding: content/t5-small-science-papers/checkpoint-55500/tokenizer_config.json (deflated 83%)
#   adding: content/t5-small-science-papers/checkpoint-55500/pytorch_model.bin (deflated 7%)
#   adding: content/t5-small-science-papers/checkpoint-55500/tokenizer.json (deflated 74%)
#   adding: content/t5-small-science-papers/checkpoint-55500/config.json (deflated 62%)
#   adding: content/t5-small-science-papers/checkpoint-55500/optimizer.pt (deflated 9%)
#   adding: content/t5-small-science-papers/checkpoint-55500/trainer_state.json (deflated 82%)
#   adding: content/t5-small-science-papers/checkpoint-55500/special_tokens_map.json (deflated 86%)
#   adding: content/t5-small-science-papers/checkpoint-55500/rng_state.pth (deflated 27%)
#   adding: content/t5-small-science-papers/checkpoint-61500/ (stored 0%)
#   adding: content/t5-small-science-papers/checkpoint-61500/scaler.pt (deflated 55%)
#   adding: content/t5-small-science-papers/checkpoint-61500/training_args.bin (deflated 47%)
#   adding: content/t5-small-science-papers/checkpoint-61500/scheduler.pt (deflated 49%)
#   adding: content/t5-small-science-papers/checkpoint-61500/tokenizer_config.json (deflated 83%)
#   adding: content/t5-small-science-papers/checkpoint-61500/pytorch_model.bin (deflated 7%)
#   adding: content/t5-small-science-papers/checkpoint-61500/tokenizer.json (deflated 74%)
#   adding: content/t5-small-science-papers/checkpoint-61500/config.json (deflated 62%)
#   adding: content/t5-small-science-papers/checkpoint-61500/optimizer.pt (deflated 9%)
#   adding: content/t5-small-science-papers/checkpoint-61500/trainer_state.json (deflated 82%)
#   adding: content/t5-small-science-papers/checkpoint-61500/special_tokens_map.json (deflated 86%)
#   adding: content/t5-small-science-papers/checkpoint-61500/rng_state.pth (deflated 27%)
#   adding: content/t5-small-science-papers/checkpoint-58500/ (stored 0%)
#   adding: content/t5-small-science-papers/checkpoint-58500/scaler.pt (deflated 55%)
#   adding: content/t5-small-science-papers/checkpoint-58500/training_args.bin (deflated 47%)
#   adding: content/t5-small-science-papers/checkpoint-58500/scheduler.pt (deflated 49%)
#   adding: content/t5-small-science-papers/checkpoint-58500/tokenizer_config.json (deflated 83%)
#   adding: content/t5-small-science-papers/checkpoint-58500/pytorch_model.bin (deflated 7%)
#   adding: content/t5-small-science-papers/checkpoint-58500/tokenizer.json (deflated 74%)
#   adding: content/t5-small-science-papers/checkpoint-58500/config.json (deflated 62%)
#   adding: content/t5-small-science-papers/checkpoint-58500/optimizer.pt (deflated 9%)
#   adding: content/t5-small-science-papers/checkpoint-58500/trainer_state.json (deflated 82%)
#   adding: content/t5-small-science-papers/checkpoint-58500/special_tokens_map.json (deflated 86%)
#   adding: content/t5-small-science-papers/checkpoint-58500/rng_state.pth (deflated 27%)
#   adding: content/t5-small-science-papers/checkpoint-55000/ (stored 0%)
#   adding: content/t5-small-science-papers/checkpoint-55000/scaler.pt (deflated 55%)
#   adding: content/t5-small-science-papers/checkpoint-55000/training_args.bin (deflated 47%)
#   adding: content/t5-small-science-papers/checkpoint-55000/scheduler.pt (deflated 49%)
#   adding: content/t5-small-science-papers/checkpoint-55000/tokenizer_config.json (deflated 83%)
#   adding: content/t5-small-science-papers/checkpoint-55000/pytorch_model.bin (deflated 7%)
#   adding: content/t5-small-science-papers/checkpoint-55000/tokenizer.json (deflated 74%)
#   adding: content/t5-small-science-papers/checkpoint-55000/config.json (deflated 62%)
#   adding: content/t5-small-science-papers/checkpoint-55000/optimizer.pt (deflated 9%)
#   adding: content/t5-small-science-papers/checkpoint-55000/trainer_state.json (deflated 82%)
#   adding: content/t5-small-science-papers/checkpoint-55000/special_tokens_map.json (deflated 86%)
#   adding: content/t5-small-science-papers/checkpoint-55000/rng_state.pth (deflated 27%)
#   adding: content/t5-small-science-papers/checkpoint-53500/ (stored 0%)
#   adding: content/t5-small-science-papers/checkpoint-53500/scaler.pt (deflated 55%)
#   adding: content/t5-small-science-papers/checkpoint-53500/training_args.bin (deflated 47%)
#   adding: content/t5-small-science-papers/checkpoint-53500/scheduler.pt (deflated 49%)
#   adding: content/t5-small-science-papers/checkpoint-53500/tokenizer_config.json (deflated 83%)
#   adding: content/t5-small-science-papers/checkpoint-53500/pytorch_model.bin (deflated 7%)
#   adding: content/t5-small-science-papers/checkpoint-53500/tokenizer.json (deflated 74%)
#   adding: content/t5-small-science-papers/checkpoint-53500/config.json (deflated 62%)
#   adding: content/t5-small-science-papers/checkpoint-53500/optimizer.pt (deflated 9%)
#   adding: content/t5-small-science-papers/checkpoint-53500/trainer_state.json (deflated 82%)
#   adding: content/t5-small-science-papers/checkpoint-53500/special_tokens_map.json (deflated 86%)
#   adding: content/t5-small-science-papers/checkpoint-53500/rng_state.pth (deflated 27%)
#   adding: content/t5-small-science-papers/checkpoint-63000/ (stored 0%)
#   adding: content/t5-small-science-papers/checkpoint-63000/scaler.pt (deflated 55%)
#   adding: content/t5-small-science-papers/checkpoint-63000/training_args.bin (deflated 47%)
#   adding: content/t5-small-science-papers/checkpoint-63000/scheduler.pt (deflated 49%)
#   adding: content/t5-small-science-papers/checkpoint-63000/tokenizer_config.json (deflated 83%)
#   adding: content/t5-small-science-papers/checkpoint-63000/pytorch_model.bin (deflated 7%)
#   adding: content/t5-small-science-papers/checkpoint-63000/tokenizer.json (deflated 74%)
#   adding: content/t5-small-science-papers/checkpoint-63000/config.json (deflated 62%)
#   adding: content/t5-small-science-papers/checkpoint-63000/optimizer.pt (deflated 9%)
#   adding: content/t5-small-science-papers/checkpoint-63000/trainer_state.json (deflated 82%)
#   adding: content/t5-small-science-papers/checkpoint-63000/special_tokens_map.json (deflated 86%)
#   adding: content/t5-small-science-papers/checkpoint-63000/rng_state.pth (deflated 27%)
#   adding: content/t5-small-science-papers/special_tokens_map.json (deflated 86%)

# %%
from google.colab import files
files.download('/content/t5-small-science-papers.zip')
